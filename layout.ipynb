# %%
from IPython.core.display import HTML

import os
import panel as pn
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='66ef173c-32bb-4ecf-a34e-78f074eaf2f4'>
#   <div id="d469f7c8-b335-4c2b-abdf-d15c89d35882" data-root-id="66ef173c-32bb-4ecf-a34e-78f074eaf2f4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Read the content of the HTML file
with open("choropleth.html", "r") as html_file:
    html_content = html_file.read()
c = HTML(html_content)
c
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <title>Bokeh Application</title>
#     <style>
#       html, body {
#         box-sizing: border-box;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#     </style>
#     <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-3.1.1.min.js"></script>
#     <script type="text/javascript">
#         Bokeh.set_log_level("info");
#     </script>
#   </head>
#   <body>
#     <div id="dba1200f-75b6-46ee-9cb4-1f70130296e4" data-root-id="p1101" style="display: contents;"></div>
#
#     <script type="application/json" id="p1232">
# ...

# %%
with open("birthdeathrate.html", "r") as html_file:
    html_content = html_file.read()
bdr = HTML(html_content)
bdr
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <title>Bokeh Application</title>
#     <style>
#       html, body {
#         box-sizing: border-box;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#     </style>
#     <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-3.1.1.min.js"></script>
#     <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-3.1.1.min.js"></script>
#     <script type="text/javascript">
#         Bokeh.set_log_level("info");
#     </script>
#   </head>
#   <body>
#     <div id="d1535add-2f3c-428a-853e-ecba67ca6a62" data-root-id="p4493" style="display: contents;"></div>
#
#     <script type="application/json" id="p13699">
# ...

# %%
with open("deathcause.html", "r") as html_file:
    html_content = html_file.read()
dc = HTML(html_content)
dc
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#     <title>Bokeh Application</title>
#     <style>
#       html, body {
#         box-sizing: border-box;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#     </style>
#     <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-3.1.1.min.js"></script>
#     <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-3.1.1.min.js"></script>
#     <script type="text/javascript">
#         Bokeh.set_log_level("info");
#     </script>
#   </head>
#   <body>
#     <div id="c5cdcec3-0ec3-4194-8f81-a3d593013f30" data-root-id="p1611" style="display: contents;"></div>
#
#     <script type="application/json" id="p1742">
# ...
